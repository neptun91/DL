# %%
import os, sys
print(os.getcwd())
current_dir = os.path.dirname(os.getcwd())
print(current_dir)
os.chdir(current_dir)

import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from ch06.simple_convnet import SimpleConvNet
from common.trainer import Trainer

# 데이터 읽기
(x_train, t_train), (x_test, t_test) = load_mnist(flatten=False)

# 시간이 오래 걸릴 경우 데이터를 줄인다.
x_train, t_train = x_train[:5000], t_train[:5000]
x_test, t_test = x_test[:1000], t_test[:1000]

max_epochs = 20

network = SimpleConvNet(input_dim=(1,28,28), 
                        conv_param = {'filter_num': 30, 'filter_size': 5, 'pad': 0, 'stride': 1},
                        hidden_size=100, output_size=10, weight_init_std=0.01)
                        
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=max_epochs, mini_batch_size=100,
                  optimizer='Adam', optimizer_param={'lr': 0.001},
                  evaluate_sample_num_per_epoch=1000)
trainer.train()

# 매개변수 보존
network.save_params("params.pkl")
print("Saved Network Parameters!")

# 그래프 그리기
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, trainer.train_acc_list, marker='o', label='train', markevery=2)
plt.plot(x, trainer.test_acc_list, marker='s', label='test', markevery=2)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# /workspaces/DL/ipynb/ch06
# /workspaces/DL/ipynb
# train loss:2.2997740215075937
# === epoch:1, train acc:0.302, test acc:0.26 ===
# train loss:2.295846405339029
# train loss:2.2919843230423833
# train loss:2.280987427741118
# train loss:2.2765736426089846
# train loss:2.264666040670649
# train loss:2.239155409548512
# train loss:2.2352635316704017
# train loss:2.1797638130647616
# train loss:2.1705156740129166
# train loss:2.119895313297369
# train loss:2.12204759636588
# train loss:2.0714258533232086
# train loss:2.0120930945810347
# train loss:1.9513247163369842
# train loss:1.9142691543455148
# train loss:1.7624355266058551
# train loss:1.7599311057637115
# train loss:1.6605252877485017
# train loss:1.5732953527931663
# train loss:1.4990465216476985
# train loss:1.3934701197915742
# train loss:1.255542972169616
# train loss:1.1701130043884032
# train loss:1.1600804035776167
# train loss:1.1426422247140762
# train loss:0.9356335249673835
# train loss:0.9532438399483254
# train loss:0.8650437026694964
# train loss:0.853647844490619
# train loss:0.807196457931457
# train loss:0.7338028154276195
# train loss:0.7950255417941666
# train loss:0.733375580155199
# train loss:0.748866877722349
# train loss:0.7594125537799995
# train loss:0.6891707624625526
# train loss:0.6986057629901471
# train loss:0.60024719285763
# train loss:0.6058006465328777
# train loss:0.7240206277050855
# train loss:0.5930857721691521
# train loss:0.6841636891680224
# train loss:0.6933730606605573
# train loss:0.5523036291923912
# train loss:0.5931583091096487
# train loss:0.5126988948659562
# train loss:0.4350574859241775
# train loss:0.5509968335145058
# train loss:0.47043844126817824
# train loss:0.6178744847948825
# === epoch:2, train acc:0.809, test acc:0.817 ===
# train loss:0.5979393331661602
# train loss:0.3323747630984157
# train loss:0.45439493320785557
# train loss:0.7095461887205201
# train loss:0.38834316529078594
# train loss:0.4725734793653811
# train loss:0.40730728121944326
# train loss:0.3854079640105868
# train loss:0.342316997849466
# train loss:0.37071673008104894
# train loss:0.4075592424578148
# train loss:0.4762465484520086
# train loss:0.4401810806213557
# train loss:0.33869350723920244
# train loss:0.44888083790149075
# train loss:0.5393740028629188
# train loss:0.43226018095455077
# train loss:0.4809803908038478
# train loss:0.33311907610209857
# train loss:0.43863085402328894
# train loss:0.427218839345214
# train loss:0.6268403207589253
# train loss:0.45617999227469214
# train loss:0.5218745310696072
# train loss:0.47985748997128835
# train loss:0.3365013742298207
# train loss:0.5669048202723981
# train loss:0.48473845840570917
# train loss:0.583789944939606
# train loss:0.5007164780594396
# train loss:0.4193265904336376
# train loss:0.5325381679137536
# train loss:0.2504336716263933
# train loss:0.31122718766771423
# train loss:0.3478584197430965
# train loss:0.32719342231582976
# train loss:0.283293073812745
# train loss:0.4840165168431757
# train loss:0.28081891046919627
# train loss:0.2770308155593976
# train loss:0.49438498588164015
# train loss:0.26121541469171206
# train loss:0.29578591314832103
# train loss:0.30038273432799856
# train loss:0.4476435203973961
# train loss:0.2703056045129922
# train loss:0.2438737967632579
# train loss:0.35867548373272146
# train loss:0.25743047261305446
# train loss:0.2398761587296084
# === epoch:3, train acc:0.892, test acc:0.862 ===
# train loss:0.34092093027549936
# train loss:0.37773450799465785
# train loss:0.4098920135627859
# train loss:0.3268916600768456
# train loss:0.2873033856330837
# train loss:0.2816723882275732
# train loss:0.31908936889183886
# train loss:0.2595618934614411
# train loss:0.26905263651939504
# train loss:0.16906004485440249
# train loss:0.3581729254323996
# train loss:0.3570923263336341
# train loss:0.3402165625743986
# train loss:0.32093810314916005
# train loss:0.3690814406838258
# train loss:0.30384205000957903
# train loss:0.3721383614329355
# train loss:0.42394533984670246
# train loss:0.3314140683090907
# train loss:0.36420154495069484
# train loss:0.301272399433082
# train loss:0.327916039204009
# train loss:0.3708820674183651
# train loss:0.30284162536745496
# train loss:0.14495574231890185
# train loss:0.27471950733794354
# train loss:0.364115234451425
# train loss:0.2265811348780958
# train loss:0.24851136485536418
# train loss:0.2879104709632028
# train loss:0.33062517183251133
# train loss:0.22562947161008873
# train loss:0.23178876963754358
# train loss:0.2688110164123759
# train loss:0.19062576414234378
# train loss:0.21888897763860182
# train loss:0.23394203181507256
# train loss:0.294032447030722
# train loss:0.3000878475654001
# train loss:0.33233997833866236
# train loss:0.1802742153300065
# train loss:0.18856772425537954
# train loss:0.3139047964228705
# train loss:0.3223754940632804
# train loss:0.22976426974105885
# train loss:0.31221058110867395
# train loss:0.20230808533355402
# train loss:0.24800592806485638
# train loss:0.2773355528020889
# train loss:0.29927348767306944
# === epoch:4, train acc:0.899, test acc:0.884 ===
# train loss:0.32018090231740415
# train loss:0.11670502660568303
# train loss:0.35767602721903885
# train loss:0.20413218626858376
# train loss:0.17068985682204482
# train loss:0.27034669377225046
# train loss:0.22534974792731513
# train loss:0.33746805105713135
# train loss:0.2809197402151811
# train loss:0.2530480098356635
# train loss:0.20815122269156772
# train loss:0.2595145734916205
# train loss:0.1357022377291976
# train loss:0.20993848421397893
# train loss:0.2893006939291413
# train loss:0.2868074229991119
# train loss:0.1812397354308651
# train loss:0.1089277730715367
# train loss:0.37420828847647447
# train loss:0.1990729667219659
# train loss:0.28214445314731784
# train loss:0.17542644916604172
# train loss:0.18970698544162917
# train loss:0.3049770486308116
# train loss:0.21636459957745013
# train loss:0.23732708481231565
# train loss:0.20938773120859103
# train loss:0.16951554588331078
# train loss:0.15264562248414015
# train loss:0.2132188788901659
# train loss:0.24199318079180937
# train loss:0.16808417824098662
# train loss:0.2419077276546188
# train loss:0.25770703235771364
# train loss:0.13312664885296943
# train loss:0.1687645701015701
# train loss:0.13521494332252615
# train loss:0.2026150026672572
# train loss:0.20224427075407142
# train loss:0.23603491388627107
# train loss:0.271672313605192
# train loss:0.19021668914524636
# train loss:0.21819823533638172
# train loss:0.3766657060175669
# train loss:0.14465543033675532
# train loss:0.19450001295605585
# train loss:0.2088823567827829
# train loss:0.3222254007050624
# train loss:0.29004489485810586
# train loss:0.2136382786075782
# === epoch:5, train acc:0.922, test acc:0.895 ===
# train loss:0.13988036118764316
# train loss:0.16294114135004345
# train loss:0.17649656418202625
# train loss:0.12555205283388182
# train loss:0.16310062195279873
# train loss:0.23218980653858384
# train loss:0.1155189737025285
# train loss:0.2670991422048379
# train loss:0.3197973094157517
# train loss:0.13137511041475972
# train loss:0.3049880166747607
# train loss:0.19856942614780163
# train loss:0.22929917720602458
# train loss:0.23567908642880994
# train loss:0.18550273686698202
# train loss:0.30484931710536356
# train loss:0.30253153155081
# train loss:0.25114315483868177
# train loss:0.2142639660100261
# train loss:0.2086604244422253
# train loss:0.2828089173034421
# train loss:0.18221142852860273
# train loss:0.37882221520561066
# train loss:0.2606064052081244
# train loss:0.13879267738398632
# train loss:0.16540495795058516
# train loss:0.13095882766975325
# train loss:0.24167703297732449
# train loss:0.19876555827964684
# train loss:0.3014340017077971
# train loss:0.24200727663037291
# train loss:0.10649003036618383
# train loss:0.19691288274682844
# train loss:0.06874565657065165
# train loss:0.15434874809972135
# train loss:0.12114799389340744
# train loss:0.1407396441800697
# train loss:0.1752080738601213
# train loss:0.2658234950267668
# train loss:0.23501217014345513
# train loss:0.21822809819777655
# train loss:0.10740831402897831
# train loss:0.2742197814674723
# train loss:0.16185940503282795
# train loss:0.2474836356834389
# train loss:0.2436858252940604
# train loss:0.11493335400558374
# train loss:0.2074372976270814
# train loss:0.14669376428846082
# train loss:0.10732615253629571
# === epoch:6, train acc:0.931, test acc:0.913 ===
# train loss:0.10114671599818596
# train loss:0.16359659014388123
# train loss:0.14844496077282873
# train loss:0.28430850788664
# train loss:0.23267922760777004
# train loss:0.11583289714373567
# train loss:0.19087353005237856
# train loss:0.2793460839918725
# train loss:0.11523321507192698
# train loss:0.12047078319137876
# train loss:0.2059076193191469
# train loss:0.19779898535925802
# train loss:0.20905499376619466
# train loss:0.19650719896710364
# train loss:0.2065270113812378
# train loss:0.14375722288165715
# train loss:0.16436852920247852
# train loss:0.1507628863761624
# train loss:0.12909849360972347
# train loss:0.22812503281627666
# train loss:0.18372437647557155
# train loss:0.11705157566236775
# train loss:0.13493688352773073
# train loss:0.2495685364588423
# train loss:0.269196870491354
# train loss:0.2763233847477812
# train loss:0.21511084051502546
# train loss:0.18398689172369326
# train loss:0.17796520637960078
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 30
#      22 network = SimpleConvNet(input_dim=(1,28,28),
#      23                         conv_param = {'filter_num': 30, 'filter_size': 5, 'pad': 0, 'stride': 1},
#      24                         hidden_size=100, output_size=10, weight_init_std=0.01)
#      26 trainer = Trainer(network, x_train, t_train, x_test, t_test,
#      27                   epochs=max_epochs, mini_batch_size=100,
#      28                   optimizer='Adam', optimizer_param={'lr': 0.001},
#      29                   evaluate_sample_num_per_epoch=1000)
# ---> 30 trainer.train()
#      32 # 매개변수 보존
#      33 network.save_params("params.pkl")
#
# File /workspaces/DL/ipynb/common/trainer.py:71, in Trainer.train(self)
#      69 def train(self):
#      70     for i in range(self.max_iter):
# ---> 71         self.train_step()
#      73     test_acc = self.network.accuracy(self.x_test, self.t_test)
#      75     if self.verbose:
#
# File /workspaces/DL/ipynb/common/trainer.py:47, in Trainer.train_step(self)
#      44 grads = self.network.gradient(x_batch, t_batch)
#      45 self.optimizer.update(self.network.params, grads)
# ---> 47 loss = self.network.loss(x_batch, t_batch)
#      48 self.train_loss_list.append(loss)
#      49 if self.verbose: print("train loss:" + str(loss))
#
# File /workspaces/DL/ipynb/ch06/simple_convnet.py:78, in SimpleConvNet.loss(self, x, t)
#      70 def loss(self, x, t):
#      71     """손실 함수를 구한다.
#      72
#      73     Parameters
#    (...)     76     t : 정답 레이블
#      77     """
# ---> 78     y = self.predict(x)
#      79     return self.last_layer.forward(y, t)
#
# File /workspaces/DL/ipynb/ch06/simple_convnet.py:66, in SimpleConvNet.predict(self, x)
#      64 def predict(self, x):
#      65     for layer in self.layers.values():
# ---> 66         x = layer.forward(x)
#      68     return x
#
# File /workspaces/DL/ipynb/common/layers.py:265, in Pooling.forward(self, x)
#     262 col = col.reshape(-1, self.pool_h*self.pool_w)
#     264 arg_max = np.argmax(col, axis=1)
# --> 265 out = np.max(col, axis=1)
#     266 out = out.reshape(N, out_h, out_w, C).transpose(0, 3, 1, 2)
#     268 self.x = x
#
# File ~/.local/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3164, in max(a, axis, out, keepdims, initial, where)
#    3052 @array_function_dispatch(_max_dispatcher)
#    3053 @set_module('numpy')
#    3054 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3055          where=np._NoValue):
#    3056     """
#    3057     Return the maximum of an array or maximum along an axis.
#    3058
#    (...)   3162     5
#    3163     """
# -> 3164     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    3165                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/.local/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
